# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Data transformation**
#
#   - generally data has 3 types of distributions
#
#     - normal disrribution
#     - positive Skewed
#     - Negative Skewed
#
# - all the maths concepts developed by assumption as data follows normal distribution
#
# - Data skew happens because of many reasons, in that one reason is ouliers
#
# - Onces we perform the outliers analysis then we can apply transformation method,if the data does not follows normality
#
# - we have some transformation method mentioned below
#
# - log transformtion
# - exponential transfprmation
# - receprocal transformation
# - square root Transformation
# - power transforamtion

# %% [markdown]
# $step-1$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $step-2$

# %% [markdown]
# $read the data$

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.95556322, 0.43808917, 0.55647158, ..., 1.04183744, 0.73544558,
#        0.04124303])

# %% [markdown]
# **step-3**

# %% [markdown]
# **plot the data**

# %%
plt.hist(exp_data,bins=20,label='exponential')
plt.show()

# %%
norm_data=np.random.normal(size=10000)
plt.hist(norm_data,bins=20,label='exponential')
plt.show()

# %% [markdown]
# **goal**
# - the goal is convert exp_data to normal distribution
# - bins= interval

# %%
**step-4**

- ** log transformation**

- log transformation means performing logaritham operations  on original data

- it is an approcah to convert

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([-0.04545435, -0.82533281, -0.58613918, ...,  0.04098592,
#        -0.30727873, -3.18827322])

# %%
plt.hist(log_data,bins=20,label='exponential')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=30,label='exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=20,label='Logorithim')
plt.legend()
plt.show()

# %% [markdown]
# **reciprocal transformation**
#
# - reciprocal will fail when value are low
#
# - for example x=0 then 1/0

# %%
x=2
1/x
# Out:
# 0.5

# %%
reciprocal_data=np.reciprocal(exp_data)
plt.hist(reciprocal_data,bins=20,label="exponential")
plt.show()

# %% [markdown]
# **square root transformation**

# %%
square_root_data=np.sqrt(exp_data)
plt.hist(square_root_data,bins=20,label="Square_Root_Data")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
log_data=np.log(exp_data)
plt.subplot(1,3,1).hist(exp_data,bins=30,label='exponential')
plt.legend()
log_data=np.log(exp_data)
plt.subplot(1,3,2).hist(log_data,bins=20,label='Logorithim')
plt.legend()
log_data=np.log(exp_data)
plt.subplot(1,3,3).hist(square_root_data,bins=20,label='square_root_data')
plt.legend()
plt.show()

# %% [markdown]
# **power transformation**
#
#   - box cox
#
#   - ye-jhonson
#
#   - it is under sklearn preprocessing
#
#   - we will apply only for positive data

# %%
from sklearn.preprocessing import power Transformer
power=powerTransformation(method
